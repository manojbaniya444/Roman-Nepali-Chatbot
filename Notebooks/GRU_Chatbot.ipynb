# %%
# For tips on running notebooks in Google Colab, see
# https://pytorch.org/tutorials/beginner/colab
# %matplotlib inline

# %% [markdown]
# NLP From Scratch: Translation with a Sequence to Sequence Network and Attention
# ===============================================================================
#
# **Author**: [Sean Robertson](https://github.com/spro)
#
# This tutorials is part of a three-part series:
#
# -   [NLP From Scratch: Classifying Names with a Character-Level
#     RNN](https://pytorch.org/tutorials/intermediate/char_rnn_classification_tutorial.html)
# -   [NLP From Scratch: Generating Names with a Character-Level
#     RNN](https://pytorch.org/tutorials/intermediate/char_rnn_generation_tutorial.html)
# -   [NLP From Scratch: Translation with a Sequence to Sequence Network
#     and
#     Attention](https://pytorch.org/tutorials/intermediate/seq2seq_translation_tutorial.html)
#
# This is the third and final tutorial on doing **NLP From Scratch**,
# where we write our own classes and functions to preprocess the data to
# do our NLP modeling tasks.
#
# In this project we will be teaching a neural network to translate from
# French to English.
#
# ``` {.sh}
# [KEY: > input, = target, < output]
#
# > il est en train de peindre un tableau .
# = he is painting a picture .
# < he is painting a picture .
#
# > pourquoi ne pas essayer ce vin delicieux ?
# = why not try that delicious wine ?
# < why not try that delicious wine ?
#
# > elle n est pas poete mais romanciere .
# = she is not a poet but a novelist .
# < she not not a poet but a novelist .
#
# > vous etes trop maigre .
# = you re too skinny .
# < you re all alone .
# ```
#
# \... to varying degrees of success.
#
# This is made possible by the simple but powerful idea of the [sequence
# to sequence network](https://arxiv.org/abs/1409.3215), in which two
# recurrent neural networks work together to transform one sequence to
# another. An encoder network condenses an input sequence into a vector,
# and a decoder network unfolds that vector into a new sequence.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/seq2seq.png)
#
# To improve upon this model we\'ll use an [attention
# mechanism](https://arxiv.org/abs/1409.0473), which lets the decoder
# learn to focus over a specific range of the input sequence.
#
# **Recommended Reading:**
#
# I assume you have at least installed PyTorch, know Python, and
# understand Tensors:
#
# -   <https://pytorch.org/> For installation instructions
# -   `/beginner/deep_learning_60min_blitz`{.interpreted-text role="doc"}
#     to get started with PyTorch in general
# -   `/beginner/pytorch_with_examples`{.interpreted-text role="doc"} for
#     a wide and deep overview
# -   `/beginner/former_torchies_tutorial`{.interpreted-text role="doc"}
#     if you are former Lua Torch user
#
# It would also be useful to know about Sequence to Sequence networks and
# how they work:
#
# -   [Learning Phrase Representations using RNN Encoder-Decoder for
#     Statistical Machine Translation](https://arxiv.org/abs/1406.1078)
# -   [Sequence to Sequence Learning with Neural
#     Networks](https://arxiv.org/abs/1409.3215)
# -   [Neural Machine Translation by Jointly Learning to Align and
#     Translate](https://arxiv.org/abs/1409.0473)
# -   [A Neural Conversational Model](https://arxiv.org/abs/1506.05869)
#
# You will also find the previous tutorials on
# `/intermediate/char_rnn_classification_tutorial`{.interpreted-text
# role="doc"} and
# `/intermediate/char_rnn_generation_tutorial`{.interpreted-text
# role="doc"} helpful as those concepts are very similar to the Encoder
# and Decoder models, respectively.
#
# **Requirements**

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

import numpy as np
from torch.utils.data import TensorDataset, DataLoader, RandomSampler

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# Loading data files
# ==================
#
# The data for this project is a set of many thousands of English to
# French translation pairs.
#
# [This question on Open Data Stack
# Exchange](https://opendata.stackexchange.com/questions/3888/dataset-of-sentences-translated-into-many-languages)
# pointed me to the open translation site <https://tatoeba.org/> which has
# downloads available at <https://tatoeba.org/eng/downloads> - and better
# yet, someone did the extra work of splitting language pairs into
# individual text files here: <https://www.manythings.org/anki/>
#
# The English to French pairs are too big to include in the repository, so
# download to `data/eng-fra.txt` before continuing. The file is a tab
# separated list of translation pairs:
#
# ``` {.sh}
# I am cold.    J'ai froid.
# ```
#
# <div style="background-color: #54c7ec; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>NOTE:</strong></div>
#
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
#
# <p>Download the data from<a href="https://download.pytorch.org/tutorial/data.zip">here</a>and extract it to the current directory.</p>
#
# </div>

# %% [markdown]
# Similar to the character encoding used in the character-level RNN
# tutorials, we will be representing each word in a language as a one-hot
# vector, or giant vector of zeros except for a single one (at the index
# of the word). Compared to the dozens of characters that might exist in a
# language, there are many many more words, so the encoding vector is much
# larger. We will however cheat a bit and trim the data to only use a few
# thousand words per language.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/word-encoding.png)

# %% [markdown]
# We\'ll need a unique index per word to use as the inputs and targets of
# the networks later. To keep track of all this we will use a helper class
# called `Lang` which has word → index (`word2index`) and index → word
# (`index2word`) dictionaries, as well as a count of each word
# `word2count` which will be used to replace rare words later.

# %%
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %% [markdown]
# The files are all in Unicode, to simplify we will turn Unicode
# characters to ASCII, make everything lowercase, and trim most
# punctuation.

# %%
# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z!?]+", r" ", s)
    return s.strip()

# %% [markdown]
# To read the data file we will split the file into lines, and then split
# lines into pairs. The files are all English → Other Language, so if we
# want to translate from Other Language → English I added the `reverse`
# flag to reverse the pairs.

# %%
"Go.	Va !".split()
# Out:
# ['Go.', 'Va', '!']

# %%
# Read the file and split into lines
lines = open("./data.txt", encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
print(pairs)
# Out:
# [['ho yo saman stock ma chha', 'yo saman stock ma chha ki chhaina ?'], ['ho yo product stock ma chha', 'kripaya yo product stock ma chha ki chhaina bhanera janakari dinus na ?'], ['yes yo item available chha', 'maile herna chahanchu ki yo item available chha ki chhaina ?'], ['ho yo item abailable chha', 'yo item abailable chha ?'], ['ho stock ma cha', 'stock ma yo item cha ki chhaina ?'], ['ho yo item stock ma chha', 'kripaya yo item stock ma chha ki nai bhannus ?'], ['ho yo product available chha', 'mero order ko lagi yo product available chha ki chhaina ?'], ['ho hami sanga yo saman chha', 'tapai ko store ma yo saman chha ?'], ['ho tapai yo product pauna saknuhuncha', 'yo product pauna sakchhu ma ?'], ['yo saman available chha', 'yo saman ko availability ke chha ?'], ['ho tapai ko store ma yo saman stock ma chha', 'tapai ko store ma yo saman stock ma chha ki chhaina ?'], ['ho yo item ajhai available chha', 'yo item ajhai available chha ?'], ['ho stock update gareko chha ra yo item ajhai chha', 'stock update garnu bhayo ki yo item ajhai chha ?'], ['ho tapai yo saman order garna saknuhuncha stock ma chha', 'maile yo saman order garnu parne chha ki stock ma chhaina ?'], ['ho yo product available chha', 'yo product ko availability check garna saknu hunchha ?'], ['ho yo item stock ma chha', 'kripaya yo item stock ma chha ki chhaina bhannus ?'], ['ho tapai yo saman online order garna saknuhuncha stock ma chha', 'yo saman online order garnu sakchhu ki stock ma chhaina ?'], ['ho yo product ajhai stock ma chha', 'yo product ajhai stock ma chha ki nai ?'], ['yo item hami ko store ma available chha', 'yo item kaha available chha ?'], ['yo saman stock ma chha', 'yo saman stock ko barema janakari dinus na'], ['ho hami sanga yo item stock ma chha', 'ke tapai sanga yo item stock ma chha ?'], ['ho yo product available nai chha', 'yo product available nai chha ki chhaina ?'], ['yo item available chha', 'kripaya malai yo item ko availability barema bhanidinuhos'], ['ho yo saman stock ma chha', 'yo saman stock ma chha bhane matra order garnu chahanchu'], ['ho hamro store ma yo product cha', 'tapai ko store ma yo product cha ki chhaina ?'], ['ho yo item ajhai available cha', 'yo item ajhai available cha ?'], ['ho yo product ko stock update cha', 'yo product ko stock update cha ?'], ['ho yo saman stock ma chha', 'kripaya yo saman ko stock barema bhanidinuhos'], ['ho yo item ko stock update gareko chha', 'yo item ko stock update garnu bhayo ?'], ['ho tapai ko store ma yo saman paunu huncha', 'tapai ko store ma yo saman pauxu ki ?'], ['ho yo product stock ma chha', 'kripaya yo product stock ma chha bhane bhanidinuhos'], ['ho tapai yo saman order garna saknuhuncha', 'maile yo saman order garna sakchu ki ?'], ['ho yo item stock ma nai chha', 'yo item stock ma nai chha ?'], ['yo product stock ma chha', 'yo product ko stock kasto chha ?'], ['ho yo saman available cha', 'yo saman available cha ki ?'], ['ho yo product stock ma nai chha', 'yo product stock ma nai chha ki chhaina ?'], ['ho tapai yo item order garna saknuhuncha', 'maile yo item order garna sakchu ki chhaina ?'], ['yo item stock ma chha', 'kripaya yo item ko stock barema janakari dinus na'], ['ho yo product ajhai pani available chha', 'yo product ajhai pani available chha ki ?'], ['yo item available chha', 'yo item ko availability barema bhanidinuhos'], ['ho yo product stock ma ajhai pani chha', 'yo product stock ma ajhai pani chha ?'], ['yo saman stock ma chha', 'kripaya malai yo saman ko stock barema janakari dinuhos'], ['ho yo item available nai chha', 'yo item available nai chha ?'], ['yo product available chha', 'kripaya yo product ko availability barema bhanidinuhos'], ['ho yo saman ko stock check garna sakchhu', 'yo saman ko stock check garna saknu huncha ?'], ['ho hamro store ma yo item chha', 'tapai ko store ma yo item chha ?'], ['ho yo product ko stock ajhai available chha', 'yo product ko stock ajhai available chha ki ?'], ['ho tapai yo saman online order garna saknuhuncha', 'yo  ...

# %%
def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")

    # Read the file and split into lines
    lines = open("./data.txt", encoding='utf-8').\
        read().strip().split('\n')

    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    # print(pairs)

    # Reverse pairs, make Lang instances
    if reverse:
        pairs = [list(reversed(p)) for p in pairs]
        input_lang = Lang(lang2)
        output_lang = Lang(lang1)
    else:
        input_lang = Lang(lang1)
        output_lang = Lang(lang2)

    return input_lang, output_lang, pairs

# %% [markdown]
# Since there are a *lot* of example sentences and we want to train
# something quickly, we\'ll trim the data set to only relatively short and
# simple sentences. Here the maximum length is 10 words (that includes
# ending punctuation) and we\'re filtering to sentences that translate to
# the form \"I am\" or \"He is\" etc. (accounting for apostrophes replaced
# earlier).

# %%
MAX_LENGTH = 30

eng_prefixes = (
    "i am ", "i m ",
    "he is", "he s ",
    "she is", "she s ",
    "you are", "you re ",
    "we are", "we re ",
    "they are", "they re "
)

def filterPair(p):
    return len(p[0].split(' ')) < MAX_LENGTH and \
        len(p[1].split(' ')) < MAX_LENGTH


def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# %% [markdown]
# The full process for preparing the data is:
#
# -   Read text file and split into lines, split lines into pairs
# -   Normalize text, filter by length and content
# -   Make word lists from sentences in pairs

# %%
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, pairs = readLangs(lang1, lang2, reverse)
    print("Read %s sentence pairs" % len(pairs))
    pairs = filterPairs(pairs)
    print("Trimmed to %s sentence pairs" % len(pairs))
    print("Counting words...")
    for pair in pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    return input_lang, output_lang, pairs

input_lang, output_lang, pairs = prepareData('eng', 'fra', True)
print(random.choice(pairs))
# Out:
# Reading lines...
# Read 225 sentence pairs
# Trimmed to 225 sentence pairs
# Counting words...
# Counted words:
# fra 88
# eng 47
# ['yo product stock ma ajhai pani chha ki chhaina ?', 'ho yo product stock ma ajhai pani chha']

# %%
pairs
# Out:
# [['yo saman stock ma chha ki chhaina ?', 'ho yo saman stock ma chha'],
#  ['kripaya yo product stock ma chha ki chhaina bhanera janakari dinus na ?',
#   'ho yo product stock ma chha'],
#  ['maile herna chahanchu ki yo item available chha ki chhaina ?',
#   'yes yo item available chha'],
#  ['yo item abailable chha ?', 'ho yo item abailable chha'],
#  ['stock ma yo item cha ki chhaina ?', 'ho stock ma cha'],
#  ['kripaya yo item stock ma chha ki nai bhannus ?',
#   'ho yo item stock ma chha'],
#  ['mero order ko lagi yo product available chha ki chhaina ?',
#   'ho yo product available chha'],
#  ['tapai ko store ma yo saman chha ?', 'ho hami sanga yo saman chha'],
#  ['yo product pauna sakchhu ma ?', 'ho tapai yo product pauna saknuhuncha'],
#  ['yo saman ko availability ke chha ?', 'yo saman available chha'],
#  ['tapai ko store ma yo saman stock ma chha ki chhaina ?',
#   'ho tapai ko store ma yo saman stock ma chha'],
#  ['yo item ajhai available chha ?', 'ho yo item ajhai available chha'],
#  ['stock update garnu bhayo ki yo item ajhai chha ?',
#   'ho stock update gareko chha ra yo item ajhai chha'],
#  ['maile yo saman order garnu parne chha ki stock ma chhaina ?',
#   'ho tapai yo saman order garna saknuhuncha stock ma chha'],
#  ['yo product ko availability check garna saknu hunchha ?',
#   'ho yo product available chha'],
#  ['kripaya yo item stock ma chha ki chhaina bhannus ?',
#   'ho yo item stock ma chha'],
#  ['yo saman online order garnu sakchhu ki stock ma chhaina ?',
#   'ho tapai yo saman online order garna saknuhuncha stock ma chha'],
#  ['yo product ajhai stock ma chha ki nai ?',
#   'ho yo product ajhai stock ma chha'],
#  ['yo item kaha available chha ?', 'yo item hami ko store ma available chha'],
#  ['yo saman stock ko barema janakari dinus na', 'yo saman stock ma chha'],
#  ['ke tapai sanga yo item stock ma chha ?',
#   'ho hami sanga yo item stock ma chha'],
#  ['yo product available nai chha ki chhaina ?',
#   'ho yo product available nai chha'],
#  ['kripaya malai yo item ko availability barema bhanidinuhos',
#   'yo item available chha'],
#  ['yo saman stock ma chha bhane matra order garnu chahanchu',
#   'ho yo saman stock ma chha'],
#  ['tapai ko store ma yo product cha ki chhaina ?',
#   'ho hamro store ma yo product cha'],
#  ['yo item ajhai available cha ?', 'ho yo item ajhai available cha'],
#  ['yo product ko stock update cha ?', 'ho yo product ko stock update cha'],
#  ['kripaya yo saman ko stock barema bhanidinuhos',
#   'ho yo saman stock ma chha'],
#  ['yo item ko stock update garnu bhayo ?',
#   'ho yo item ko stock update gareko chha'],
#  ['tapai ko store ma yo saman pauxu ki ?',
#   'ho tapai ko store ma yo saman paunu huncha'],
#  ['kripaya yo product stock ma chha bhane bhanidinuhos',
#   'ho yo product stock ma chha'],
#  ['maile yo saman order garna sakchu ki ?',
#   'ho tapai yo saman order garna saknuhuncha'],
#  ['yo item stock ma nai chha ?', 'ho yo item stock ma nai chha'],
#  ['yo product ko stock kasto chha ?', 'yo product stock ma chha'],
#  ['yo saman available cha ki ?', 'ho yo saman available cha'],
#  ['yo product stock ma nai chha ki chhaina ?',
#   'ho yo product stock ma nai chha'],
#  ['maile yo item order garna sakchu ki chhaina ?',
#   'ho tapai yo item order garna saknuhuncha'],
#  ['kripaya yo item ko stock barema janakari dinus na',
#   'yo item stock ma chha'],
#  ['yo product ajhai pani available chha ki ?',
#   'ho yo product ajhai pani available chha'],
#  ['yo item ko availability barema bhanidinuhos', 'yo item available chha'],
#  ['yo product stock ma ajhai pani chha ?',
#   'ho yo product stock ma ajhai pani chha'],
#  ['kripaya malai yo saman ko stock barema janakari dinuhos',
#   'yo saman stock ma chha'],
#  ['yo item available nai chha ?', 'ho yo item available nai chha'],
#  ['kripaya yo product ko availability barema bhanidinuhos',
#   'yo product available chha'],
#  ['yo saman ko stock check garna saknu huncha ?',
#   'ho yo saman ko stock check garna sakchhu'],
#  ['tapai ko store ma yo item chha ?', 'ho hamro store ma yo item chha'],
#  ['yo product ko stock ajhai available chha ki ?',
#   'ho yo product ko stock ajhai available chha'],
#  ['yo saman online order garnu sakchhu ki chhaina ?',
#   'ho tapai yo saman online order garna saknuhuncha'],
#  ['yo item ko stock kasto chha bhannus na ?',
#   'yo item ko stock available chha'],
#  ['yo product available chha ki nai ?', 'ho yo product available chha'],
#  ['yo saman ko availability barema bhanidinuhos na',
#   'yo saman available chha'],
#  ['maile yo item order garna milchha ki ?',
#   'ho tapai yo item order garna milchha'],
#  ['yo product stock ma ajhai pani chha ki chhaina ?',
#   'ho yo product stock ma ajhai pani chha'],
#  ['kripaya malai yo saman ko availability barema bhanidinuhos',
#   'yo saman available chha'],
#  ['yo item stock ma ajhai chha ki nai ?', 'ho yo item stock ma ajhai chha'],
#  ['yo product online available chha ki chhaina ?',
#   'ho yo product online available chha'],
#  ['yo saman store ma chha ki chhaina ?', 'ho yo saman store ma chha'],
#  ['yo item available chha bhane order garna chahanchu',
#   'ho yo item available chha'],
#  ['yo product ko availability check garna sakchhu ?',
#   'ho tapai yo product ko availability check garna saknuhuncha'],
#  ['tapai ko store ma yo saman stock ma chha ?',
#   'ho hami ko store ma yo saman stock ma chha'],
#  ['yo product ajhai available chha ki ?',
#   'ho yo product ajhai available chha'],
#  ['yo saman ko stock barema janakari dinuhos na', 'yo saman stock ma chha'],
#  ['yo item ajhai stock ma chha ki ?', 'ho yo item ajhai stock ma chha'],
#  ['yo product stock ma available chha ki chhaina ?',
#   'ho yo product stock ma available chha'],
#  ['yo saman ko stock ajhai available chha ki ?',
#   'ho yo saman ko stock ajhai available chha'],
#  ['yo item ko availability ajhai chha ki chhaina ?',
#   'ho yo item ko availability ajhai chha'],
#  ['yo product stock ma ajhai chha ?', 'ho yo product stock ma ajhai chha'],
#  ['yo saman stock ma chha bhane matra order garna chahanchu',
#   'ho yo saman stock ma chha'],
#  ['yo item ko stock barema update dinuhos na', 'yo item stock ma chha'],
#  ['kripaya yo product ko stock update cha ki chhaina ?',
#   'ho yo product ko stock update cha'],
#  ['kripaya malai yo product stock ma chha ki chhaina bhanera thap janakari dinus na ?',
#   'ho yo product stock ma chha tapai order garna saknuhuncha'],
#  ['yo saman ko availability ke chha ? maile order garnai parne bhayo',
#   'yo saman stock ma chha tapai aram le order garnu saknuhuncha'],
#  ['yo item stock ma chha ki ? maile ajhai nai order garnu parcha',
#   'ho yo item stock ma chha tapai ajhai nai order garnu saknuhuncha'],
#  ['kripaya janakari dinus ki yo saman hami ko store ma ajhai stock ma chha ki chhaina ?',
#   'ho yo saman hamro store ma ajhai stock ma chha'],
#  ['yo product stock ma nai chha bhane matra order garnu chahanchu',
#   'ho yo product stock ma nai chha tapai order garna saknuhuncha'],
#  ['kripaya yo item ko availability check garera bhanidinuhos na ?',
#   'yo item stock ma chha tapai aram le kinmel garna saknuhuncha'],
#  ['yo product stock ma ajhai chha bhane janakari dinuhos please',
#   'ho yo product stock ma ajhai chha tapai le yo order garna saknuhuncha'],
#  ['yo saman hami ko store ma ajhai pani available chha ki nai ?',
#   'ho yo saman hamro store ma ajhai pani available chha'],
#  ['maile yo item stock ma chha bhane order garna sakchhu ?',
#   'ho yo item stock ma chha tapai le ajhai nai order garna saknuhuncha'],
#  ['kripaya malai janakari dinus ki yo product ko availability ke chha ?',
#   'yo product ajhai available chha tapai le ajhai order garna saknuhuncha'],
#  ['yo item stock ma ajhai pani chha ki ?',
#   'ho yo item stock ma ajhai pani chha tapai order garna saknuhuncha'],
#  ['yo saman ko stock update garnu bhayo bhane janakari dinuhos',
#   'ho yo saman ko stock update gareko chha ra ajhai pani available chha'],
#  ['yo product ko availability barema thap janakari dinus na',
#   'yo product ajhai stock ma chha tapai le aram le kinmel garna saknuhuncha'],
#  ['maile yo saman order garna milchha ki nai ? yo stock ma chha bhane',
#   'ho yo saman stock ma chha tapai le order garna milchha'],
#  ['kripaya yo item ko stock update cha ki chhaina bhanera bhanidinuhos',
#   'ho yo item ko stock update cha ra ajhai available chha'],
#  ['yo product stock ma chha bhane matra maile order garna chahanchu',
#   'ho yo product stock ma chha tapai aram le order garna saknuhuncha'],
#  ['yo saman ko stock ma chha ki nai ? maile order garna parcha',
#   'ho yo saman stock ma chha tapai le ajhai nai order garna saknuhuncha'],
#  ['yo item ajhai pani available chha ki chhaina ?',
#   'ho yo item ajhai pani available chha'],
#  ['kripaya yo product ko stock barema janakari dinuhos na',
#   'yo product stock ma chha tapai le order garna saknuhuncha'],
#  ['yo saman ko availability check garna saknu hunchha ki ?',
#   'ho yo saman available chha tapai le order garna saknuhuncha'],
#  ['yo product stock ma nai chha bhane bhanidinuhos please',
#   'ho yo product stock ma nai chha'],
#  ['kripaya malai janakari dinus ki yo item ajhai available chha ki chhaina ?',
#   'ho yo item ajhai available chha'],
#  ['yo saman ko stock update bhayo ki chhaina ? maile order garna parcha',
#   'ho yo saman ko stock update bhayo ra ajhai stock ma chha'],
#  ['yo product ko availability barema bhanidinuhos na please',
#   'yo product ajhai pani available chha'],
#  ['yo item stock ma chha bhane maile order garnu chahanchu',
#   'ho yo item stock ma chha tapai order garna saknuhuncha'],
#  ['kripaya yo product stock ma chha ki chhaina bhanera janakari dinuhos',
#   'ho yo product stock ma chha'],
#  ['yo saman stock ma ajhai chha bhane matra maile kinmel garnu chahanchu',
#   'ho yo saman stock ma ajhai chha'],
#  ['yo item ajhai stock ma chha ki nai bhanera malai janakari dinuhos',
#   'ho yo item ajhai stock ma chha'],
#  ['yo product ko stock ajhai available chha ki nai ?',
#   'ho yo product ko stock ajhai available chha'],
#  ['kripaya malai janakari dinus ki yo saman hami ko store ma stock ma chha ki chhaina ?',
#   'ho yo saman hamro store ma stock ma chha'],
#  ['yo item stock ma chha bhane matra maile order garnu chahanchu',
#   'ho yo item stock ma chha tapai order garna saknuhuncha'],
#  ['yo product ko availability check garna sakchhu bhane janakari dinuhos',
#   'ho tapai yo product ko availability check garna saknuhuncha yo available chha'],
#  ['yo saman ko stock ajhai update chha ki ?',
#   'ho yo saman ko stock ajhai update chha'],
#  ['kripaya malai yo product ko availability barema thap janakari dinuhos',
#   'yo product ajhai available chha tapai le order garna saknuhuncha'],
#  ['yo item ko stock ma chha ki nai bhanera malai janakari dinuhos',
#   'ho yo item stock ma chha'],
#  ['yo saman ko availability ajhai chha bhane bhanidinuhos please',
#   'ho yo saman ajhai available chha'],
#  ['yo product stock ma ajhai chha ki chhaina ?',
#   'ho yo product stock ma ajhai chha'],
#  ['kripaya yo item ko stock update gareko chha ki chhaina bhanera janakari dinuhos',
#   'ho yo item ko stock update gareko chha ra ajhai available chha'],
#  ['yo saman stock ma chha ki chhaina bhanera confirm garidinuhos na',
#   'ho yo saman stock ma chha'],
#  ['yo product ko availability ajhai pani chha ki ?',
#   'ho yo product ko availability ajhai pani chha'],
#  ['yo item stock ma nai chha bhane order garna milchha ?',
#   'ho yo item stock ma nai chha tapai order garna milchha'],
#  ['kripaya malai yo product stock ma chha ki chhaina bhanera janakari dinuhos',
#   'ho yo product stock ma chha'],
#  ['yo saman stock ma ajhai pani available chha ki chhaina ?',
#   'ho yo saman stock ma ajhai pani available chha'],
#  ['yo item stock ma chha bhane matra maile order garnu chahanchu',
#   'ho yo item stock ma chha tapai order garna saknuhuncha'],
#  ['yo product ajhai pani available chha bhane bhanidinuhos',
#   'ho yo product ajhai pani available chha'],
#  ['kripaya yo saman ko availability check garna saknu huncha ki ?',
#   'ho yo saman ko availability check garna sakchhu ajhai stock ma chha'],
#  ['yo item stock ma chha ki chhaina bhanera janakari dinus na please',
#   'ho yo item stock ma chha'],
#  ['yo product ko availability check garna sakchhu bhane bhanidinuhos',
#   'ho tapai yo product ko availability check garna saknuhuncha ajhai stock ma chha'],
#  ['yo saman stock ma ajhai chha ki chhaina ?',
#   'ho yo saman stock ma ajhai chha'],
#  ['yo item ko stock ajhai update chha ki chhaina ?',
#   'ho yo item ko stock ajhai update chha'],
#  ['kripaya yo product stock ma chha bhane bhanidinuhos',
#   'ho yo product stock ma chha'],
#  ['yo saman ko availability ajhai chha ki chhaina bhanera janakari dinuhos',
#   'ho yo saman ajhai available chha'],
#  ['yo item stock ma chha ki chhaina bhanera janakari dinuhos please',
#   'ho yo item stock ma chha'],
#  ['yo product ko stock ajhai available chha ki nai ?',
#   'ho yo product ko stock ajhai available chha'],
#  ['kripaya malai yo saman ko stock barema thap janakari dinuhos',
#   'yo saman stock ma chha tapai le order garna saknuhuncha'],
#  ['yo item ko stock ajhai update chha bhane bhanidinuhos',
#   'ho yo item ko stock ajhai update chha'],
#  ['yo product stock ma chha ki chhaina bhanera janakari dinuhos',
#   'ho yo product stock ma chha'],
#  ['yo saman stock ma ajhai pani chha bhane bhanidinuhos please',
#   'ho yo saman stock ma ajhai pani chha'],
#  ['yo item ko availability check garna sakchhu ki chhaina ?',
#   'ho tapai yo item ko availability check garna saknuhuncha yo available chha'],
#  ['kripaya malai yo product stock ma chha ki chhaina bhanera janakari dinuhos na',
#   'ho yo product stock ma chha'],
#  ['yo saman ko availability ajhai chha ki nai bhanera confirm garidinuhos',
#   'ho yo saman ajhai available chha'],
#  ['yo item stock ma ajhai chha ki chhaina bhanera malai janakari dinuhos',
#   'ho yo item stock ma ajhai chha'],
#  ['yo product ko stock update cha bhane bhanidinuhos please',
#   'ho yo product ko stock update cha'],
#  ['kripaya yo saman stock ma chha ki chhaina bhanera confirm garidinuhos',
#   'ho yo saman stock ma chha'],
#  ['yo item ko availability barema thap janakari dinuhos na',
#   'yo item ajhai available chha'],
#  ['yo product stock ma chha ki nai bhanera janakari dinuhos na',
#   'ho yo product stock ma chha'],
#  ['yo saman ko stock update cha ki chhaina bhane bhanidinuhos please',
#   'ho yo saman ko stock update cha'],
#  ['yo item stock ma chha bhane maile order garnu chahanchu',
#   'ho yo item stock ma chha tapai order garna saknuhuncha'],
#  ['kripaya malai yo product ko availability barema bhanidinuhos na',
#   'yo product ajhai available chha'],
#  ['yo saman stock ma ajhai pani chha ki chhaina bhanera janakari dinuhos',
#   'ho yo saman stock ma ajhai pani chha'],
#  ['yo item ko stock ajhai update cha ki nai ?',
#   'ho yo item ko stock ajhai update cha'],
#  ['yo product stock ma ajhai chha bhane janakari dinuhos',
#   'ho yo product stock ma ajhai chha'],
#  ['yo saman ko availability ajhai chha bhane bhanidinuhos na please',
#   'ho yo saman ajhai available chha'],
#  ['yo item stock ma chha bhane matra maile order garna chahanchu',
#   'ho yo item stock ma chha tapai order garna saknuhuncha'],
#  ['yo product ajhai pani available chha ki chhaina bhanera janakari dinuhos',
#   'ho yo product ajhai pani available chha'],
#  ['kripaya yo saman ko availability check garna saknuhuncha ki nai ?',
#   'ho yo saman ko availability check garna sakchhu ajhai stock ma chha'],
#  ['yo item stock ma chha ki nai bhanera malai janakari dinuhos na',
#   'ho yo item stock ma chha'],
#  ['yo product ko availability check garna milchha bhane bhanidinuhos',
#   'ho tapai yo product ko availability check garna saknuhuncha ajhai stock ma chha'],
#  ['yo saman stock ma ajhai chha bhane janakari dinuhos please',
#   'ho yo saman stock ma ajhai chha'],
#  ['yo item ko stock ajhai update chha ki nai ?',
#   'ho yo item ko stock ajhai update chha'],
#  ['kripaya yo product stock ma chha bhane bhanidinuhos',
#   'ho yo product stock ma chha'],
#  ['yo saman ko availability ajhai chha ki chhaina bhanera janakari dinuhos',
#   'ho yo saman ajhai available chha'],
#  ['yo item stock ma chha ki chhaina bhanera janakari dinuhos please',
#   'ho yo item stock ma chha'],
#  ['yo product ko stock ajhai available chha ki nai ?',
#   'ho yo product ko stock ajhai available chha'],
#  ['kripaya malai yo saman ko stock barema thap janakari dinuhos',
#   'yo saman stock ma chha tapai le order garna saknuhuncha'],
#  ['yo item ko stock ajhai update chha bhane bhanidinuhos',
#   'ho yo item ko stock ajhai update chha'],
#  ['yo product stock ma chha ki chhaina bhanera janakari dinuhos',
#   'ho yo product stock ma chha'],
#  ['yo saman stock ma ajhai pani chha bhane bhanidinuhos please',
#   'ho yo saman stock ma ajhai pani chha'],
#  ['yo item ko availability check garna sakchhu ki chhaina ?',
#   'ho tapai yo item ko availability check garna saknuhuncha yo available chha'],
#  ['kripaya malai yo product stock ma chha ki chhaina bhanera janakari dinuhos na',
#   'ho yo product stock ma chha'],
#  ['yo saman ko availability ajhai chha ki nai bhanera confirm garidinuhos',
#   'ho yo saman ajhai available chha'],
#  ['yo item stock ma ajhai chha ki chhaina bhanera malai janakari dinuhos',
#   'ho yo item stock ma ajhai chha'],
#  ['yo product ko stock update cha bhane bhanidinuhos please',
#   'ho yo product ko stock update cha'],
#  ['kripaya yo saman stock ma chha ki chhaina bhanera confirm garidinuhos',
#   'ho yo saman stock ma chha'],
#  ['yo item ko availability barema thap janakari dinuhos na',
#   'yo item ajhai available chha'],
#  ['yo product stock ma chha ki nai bhanera janakari dinuhos na',
#   'ho yo product stock ma chha'],
#  ['yo saman ko stock update cha ki chhaina bhane bhanidinuhos please',
#   'ho yo saman ko stock update cha'],
#  ['yo item stock ma chha bhane maile order garnu chahanchu',
#   'ho yo item stock ma chha tapai order garna saknuhuncha'],
#  ['kripaya malai yo product ko availability barema bhanidinuhos na',
#   'yo product ajhai available chha'],
#  ['yo saman stock ma ajhai pani chha ki chhaina bhanera janakari dinuhos',
#   'ho yo saman stock ma ajhai pani chha'],
#  ['dherai bhayena yo saman ajhai stock ma chha ki chhaina ?',
#   'ho yo saman ajhai stock ma chha tapai le order garna saknuhuncha'],
#  ['yo product stock ma chhaina bhane dherai dukha lagcha ke yo stock ma chha ?',
#   'ho yo product stock ma chha tapai le aaram le order garna saknuhuncha'],
#  ['yo item ko stock barema malai janakari dinus na order garnai parcha',
#   'yo item stock ma chha tapai le order garna saknuhuncha'],
#  ['sakdo chhito malai yo saman stock ma chha ki chhaina bhanidinuhos please',
#   'ho yo saman stock ma chha'],
#  ['asha chha ki yo product ajhai stock ma chha ? order garnu chahanchu',
#   'ho yo product ajhai stock ma chha tapai le order garna saknuhuncha'],
#  ['yo saman stock ma chha bhane matra maile order garna chahanchu kripaya bhanidinuhos',
#   'ho yo saman stock ma chha tapai le order garna saknuhuncha'],
#  ['yo product stock ma nai chha bhane malai khusi lagcha ke yo stock ma chha ?',
#   'ho yo product stock ma chha tapai le order garna saknuhuncha'],
#  ['dherai utsukta chha yo item ajhai stock ma chha ki chhaina ?',
#   'ho yo item ajhai stock ma chha'],
#  ['yo saman ko availability barema malai janakari dinus na ajhai stock ma chha ki ?',
#   'ho yo saman ajhai stock ma chha'],
#  ['yo product stock ma chha bhane kripaya malai bhanidinuhos na',
#   'ho yo product stock ma chha'],
#  ['yo item ko stock update barema malai janakari dinus kati excited chhu',
#   'yo item ko stock update chha ra ajhai available chha'],
#  ['yo saman stock ma ajhai pani chha bhane kripaya malai thaha dinuhos',
#   'ho yo saman stock ma ajhai pani chha'],
#  ['yo product ko availability check garna milchha ? malai kina parcha',
#   'ho tapai yo product ko availability check garna saknuhuncha yo available chha'],
#  ['yo item stock ma ajhai chha ki ? kripaya malai confirm garidinuhos',
#   'ho yo item stock ma ajhai chha'],
#  ['yo saman stock ma chha bhane matra maile order garnu chahanchu dherai important chha',
#   'ho yo saman stock ma chha tapai le order garna saknuhuncha'],
#  ['yo product ko stock ajhai available chha ki nai ? dherai utsukta lagyo',
#   'ho yo product ko stock ajhai available chha'],
#  ['yo item ko stock ma ajhai chha bhane kripaya malai janakari dinuhos',
#   'ho yo item stock ma ajhai chha'],
#  ['yo saman ajhai stock ma chha ki chhaina ? please bhanidinuhos',
#   'ho yo saman ajhai stock ma chha'],
#  ['yo product stock ma ajhai pani available chha ki nai ?',
#   'ho yo product stock ma ajhai pani available chha'],
#  ['yo item ko stock update barema malai thap janakari dinuhos ajhai available chha ki ?',
#   'yo item ko stock update chha ra ajhai available chha'],
#  ['yo saman stock ma chha bhane matra maile order garnu sakchhu kripaya confirm garidinuhos',
#   'ho yo saman stock ma chha tapai le order garna saknuhuncha'],
#  ['yo product ko availability check garna sakchhu bhane kripaya malai bhanidinuhos',
#   'ho tapai yo product ko availability check garna saknuhuncha ajhai stock ma chha'],
#  ['yo item stock ma ajhai pani chha ki chhaina bhanera confirm garidinuhos',
#   'ho yo item stock ma ajhai pani chha'],
#  ['yo saman ko stock update chha bhane malai khusi lagcha ajhai available chha ki ?',
#   'ho yo saman ko stock update chha ra ajhai available chha'],
#  ['yo product stock ma chha bhane kripaya malai janakari dinuhos na',
#   'ho yo product stock ma chha'],
#  ['yo item ko availability barema thap janakari dinuhos ajhai stock ma chha ki ?',
#   'ho yo item ajhai stock ma chha'],
#  ['yo saman stock ma ajhai pani available chha ki ? malai kina chahinchha',
#   'ho yo saman stock ma ajhai pani available chha'],
#  ['yo product stock ma nai chha bhane order garna milchha ?',
#   'ho yo product stock ma nai chha tapai order garna milchha'],
#  ['kripaya yo item ko stock update barema malai janakari dinuhos kati utsuk chhu',
#   'yo item ko stock update chha ra ajhai available chha'],
#  ['yo saman ko stock ma ajhai chha ki chhaina ? please bhanidinuhos',
#   'ho yo saman stock ma ajhai chha'],
#  ['yo product ajhai pani available chha bhane kripaya malai bhanidinuhos',
#   'ho yo product ajhai pani available chha'],
#  ['yo item ko stock update cha bhane bhanidinuhos dherai excited chhu',
#   'ho yo item ko stock update cha ra ajhai available chha'],
#  ['yo saman ajhai stock ma chha ki chhaina bhanera malai janakari dinuhos',
#   'ho yo saman ajhai stock ma chha'],
#  ['yo product stock ma ajhai available chha ki nai ? please bhanidinuhos',
#   'ho yo product stock ma ajhai available chha'],
#  ['yo item ko stock ajhai update chha bhane malai bhanidinuhos',
#   'ho yo product aba chitai aaucha hai'],
#  ['yo item ko stock ajhai update chha bhane kripaya malai thap janakari dinuhos',
#   'ho yo item ko stock update chha ra tapai order garna saknuhuncha'],
#  ['yo product stock ma chha bhane kripaya malai janakari dinuhos na kati utsuk chhu',
#   'ho yo product stock ma chha tapai le order garna saknuhuncha'],
#  ['yo item ko stock ajhai pani chha ki chhaina ? thap janakari dinus',
#   'ho yo item ko stock ajhai pani chha'],
#  ['yo saman ko stock update chha ki chhaina ? kripaya malai thaha dinuhos',
#   'ho yo saman ko stock update chha ra tapai order garna saknuhuncha'],
#  ['yo product stock ma ajhai chha ki nai ? kripaya bhanidinuhos',
#   'ho yo product stock ma ajhai chha'],
#  ['yo saman stock ma chha bhane kripaya malai bhanidinuhos kati utsuk chhu',
#   'ho yo saman stock ma chha tapai le order garna saknuhuncha'],
#  ['yo item ko availability barema malai janakari dinuhos ajhai stock ma chha ki ?',
#   'ho yo item ajhai stock ma chha'],
#  ['yo product ajhai pani available chha bhane kripaya malai thap janakari dinuhos',
#   'ho yo product ajhai pani available chha'],
#  ['yo saman ko stock update cha bhane kripaya malai bhanidinuhos dherai excited chhu',
#   'ho yo saman ko stock update cha ra tapai order garna saknuhuncha'],
#  ['yo item stock ma ajhai chha ki chhaina ? kripaya thap janakari dinus',
#   'ho yo item stock ma ajhai chha'],
#  ['yo product ko stock ajhai available chha ki nai ? kripaya bhanidinuhos',
#   'ho yo product ko stock ajhai available chha'],
#  ['yo saman stock ma ajhai pani available chha ki chhaina ? kripaya malai thap janakari dinuhos',
#   'ho yo saman stock ma ajhai pani available chha'],
#  ['yo item ko stock update cha bhane kripaya malai bhanidinuhos dherai utsuk chhu',
#   'ho yo item ko stock update cha ra tapai order garna saknuhuncha'],
#  ['yo product stock ma chha ki nai ? kripaya bhanidinuhos',
#   'ho yo product stock ma chha'],
#  ['yo saman ko availability ajhai chha ki nai ? kripaya malai thap janakari dinuhos',
#   'ho yo saman ajhai available chha'],
#  ['yo item stock ma ajhai pani chha ki chhaina ? kripaya thap janakari dinus',
#   'ho yo item stock ma ajhai pani chha'],
#  ['yo product ko stock update chha bhane kripaya malai bhanidinuhos dherai excited chhu',
#   'ho yo product ko stock update chha ra tapai order garna saknuhuncha'],
#  ['yo saman stock ma ajhai chha ki chhaina ? kripaya thap janakari dinuhos',
#   'ho yo saman stock ma ajhai chha'],
#  ['yo item ko availability ajhai pani chha ki chhaina ? kripaya thap janakari dinus',
#   'ho yo item ko availability ajhai pani chha'],
#  ['yo product stock ma ajhai pani available chha ki chhaina ? kripaya malai thap janakari dinuhos',
#   'ho yo product stock ma ajhai pani available chha']]

# %% [markdown]
# The Seq2Seq Model
# =================
#
# A Recurrent Neural Network, or RNN, is a network that operates on a
# sequence and uses its own output as input for subsequent steps.
#
# A [Sequence to Sequence network](https://arxiv.org/abs/1409.3215), or
# seq2seq network, or [Encoder Decoder
# network](https://arxiv.org/pdf/1406.1078v3.pdf), is a model consisting
# of two RNNs called the encoder and decoder. The encoder reads an input
# sequence and outputs a single vector, and the decoder reads that vector
# to produce an output sequence.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/seq2seq.png)
#
# Unlike sequence prediction with a single RNN, where every input
# corresponds to an output, the seq2seq model frees us from sequence
# length and order, which makes it ideal for translation between two
# languages.
#
# Consider the sentence `Je ne suis pas le chat noir` →
# `I am not the black cat`. Most of the words in the input sentence have a
# direct translation in the output sentence, but are in slightly different
# orders, e.g. `chat noir` and `black cat`. Because of the `ne/pas`
# construction there is also one more word in the input sentence. It would
# be difficult to produce a correct translation directly from the sequence
# of input words.
#
# With a seq2seq model the encoder creates a single vector which, in the
# ideal case, encodes the \"meaning\" of the input sequence into a single
# vector --- a single point in some N dimensional space of sentences.

# %% [markdown]
# The Encoder
# ===========
#
# The encoder of a seq2seq network is a RNN that outputs some value for
# every word from the input sentence. For every input word the encoder
# outputs a vector and a hidden state, and uses the hidden state for the
# next input word.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/encoder-network.png)

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size, dropout_p=0.1):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, input):
        embedded = self.dropout(self.embedding(input))
        output, hidden = self.gru(embedded)
        return output, hidden

# %% [markdown]
# The Decoder
# ===========
#
# The decoder is another RNN that takes the encoder output vector(s) and
# outputs a sequence of words to create the translation.

# %% [markdown]
# Simple Decoder
# ==============
#
# In the simplest seq2seq decoder we use only last output of the encoder.
# This last output is sometimes called the *context vector* as it encodes
# context from the entire sequence. This context vector is used as the
# initial hidden state of the decoder.
#
# At every step of decoding, the decoder is given an input token and
# hidden state. The initial input token is the start-of-string `<SOS>`
# token, and the first hidden state is the context vector (the encoder\'s
# last hidden state).
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/decoder-network.png)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)

    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        decoder_hidden = encoder_hidden
        decoder_outputs = []

        for i in range(MAX_LENGTH):
            decoder_output, decoder_hidden  = self.forward_step(decoder_input, decoder_hidden)
            decoder_outputs.append(decoder_output)

            if target_tensor is not None:
                # Teacher forcing: Feed the target as the next input
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
            else:
                # Without teacher forcing: use its own predictions as the next input
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input

        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        return decoder_outputs, decoder_hidden, None # We return `None` for consistency in the training loop

    def forward_step(self, input, hidden):
        output = self.embedding(input)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.out(output)
        return output, hidden

# %% [markdown]
# I encourage you to train and observe the results of this model, but to
# save space we\'ll be going straight for the gold and introducing the
# Attention Mechanism.

# %% [markdown]
# Attention Decoder
# =================
#
# If only the context vector is passed between the encoder and decoder,
# that single vector carries the burden of encoding the entire sentence.
#
# Attention allows the decoder network to \"focus\" on a different part of
# the encoder\'s outputs for every step of the decoder\'s own outputs.
# First we calculate a set of *attention weights*. These will be
# multiplied by the encoder output vectors to create a weighted
# combination. The result (called `attn_applied` in the code) should
# contain information about that specific part of the input sequence, and
# thus help the decoder choose the right output words.
#
# ![](https://i.imgur.com/1152PYf.png)
#
# Calculating the attention weights is done with another feed-forward
# layer `attn`, using the decoder\'s input and hidden state as inputs.
# Because there are sentences of all sizes in the training data, to
# actually create and train this layer we have to choose a maximum
# sentence length (input length, for encoder outputs) that it can apply
# to. Sentences of the maximum length will use all the attention weights,
# while shorter sentences will only use the first few.
#
# ![](https://pytorch.org/tutorials/_static/img/seq-seq-images/attention-decoder-network.png)
#
# Bahdanau attention, also known as additive attention, is a commonly used
# attention mechanism in sequence-to-sequence models, particularly in
# neural machine translation tasks. It was introduced by Bahdanau et al.
# in their paper titled [Neural Machine Translation by Jointly Learning to
# Align and Translate](https://arxiv.org/pdf/1409.0473.pdf). This
# attention mechanism employs a learned alignment model to compute
# attention scores between the encoder and decoder hidden states. It
# utilizes a feed-forward neural network to calculate alignment scores.
#
# However, there are alternative attention mechanisms available, such as
# Luong attention, which computes attention scores by taking the dot
# product between the decoder hidden state and the encoder hidden states.
# It does not involve the non-linear transformation used in Bahdanau
# attention.
#
# In this tutorial, we will be using Bahdanau attention. However, it would
# be a valuable exercise to explore modifying the attention mechanism to
# use Luong attention.

# %%
class BahdanauAttention(nn.Module):
    def __init__(self, hidden_size):
        super(BahdanauAttention, self).__init__()
        self.Wa = nn.Linear(hidden_size, hidden_size)
        self.Ua = nn.Linear(hidden_size, hidden_size)
        self.Va = nn.Linear(hidden_size, 1)

    def forward(self, query, keys):
        scores = self.Va(torch.tanh(self.Wa(query) + self.Ua(keys)))
        scores = scores.squeeze(2).unsqueeze(1)

        weights = F.softmax(scores, dim=-1)
        context = torch.bmm(weights, keys)

        return context, weights

class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1):
        super(AttnDecoderRNN, self).__init__()
        self.embedding = nn.Embedding(output_size, hidden_size)
        self.attention = BahdanauAttention(hidden_size)
        self.gru = nn.GRU(2 * hidden_size, hidden_size, batch_first=True)
        self.out = nn.Linear(hidden_size, output_size)
        self.dropout = nn.Dropout(dropout_p)

    def forward(self, encoder_outputs, encoder_hidden, target_tensor=None):
        batch_size = encoder_outputs.size(0)
        decoder_input = torch.empty(batch_size, 1, dtype=torch.long, device=device).fill_(SOS_token)
        decoder_hidden = encoder_hidden
        decoder_outputs = []
        attentions = []

        for i in range(MAX_LENGTH):
            decoder_output, decoder_hidden, attn_weights = self.forward_step(
                decoder_input, decoder_hidden, encoder_outputs
            )
            decoder_outputs.append(decoder_output)
            attentions.append(attn_weights)

            if target_tensor is not None:
                # Teacher forcing: Feed the target as the next input
                decoder_input = target_tensor[:, i].unsqueeze(1) # Teacher forcing
            else:
                # Without teacher forcing: use its own predictions as the next input
                _, topi = decoder_output.topk(1)
                decoder_input = topi.squeeze(-1).detach()  # detach from history as input

        decoder_outputs = torch.cat(decoder_outputs, dim=1)
        decoder_outputs = F.log_softmax(decoder_outputs, dim=-1)
        attentions = torch.cat(attentions, dim=1)

        return decoder_outputs, decoder_hidden, attentions


    def forward_step(self, input, hidden, encoder_outputs):
        embedded =  self.dropout(self.embedding(input))

        query = hidden.permute(1, 0, 2)
        context, attn_weights = self.attention(query, encoder_outputs)
        input_gru = torch.cat((embedded, context), dim=2)

        output, hidden = self.gru(input_gru, hidden)
        output = self.out(output)

        return output, hidden, attn_weights

# %% [markdown]
# <div style="background-color: #54c7ec; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>NOTE:</strong></div>
#
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
#
# <p>There are other forms of attention that work around the lengthlimitation by using a relative position approach. Read about "localattention" in <a href="https://arxiv.org/abs/1508.04025">Effective Approaches to Attention-based Neural MachineTranslation</a>.</p>
#
# </div>
#
# Training
# ========
#
# Preparing Training Data
# -----------------------
#
# To train, for each pair we will need an input tensor (indexes of the
# words in the input sentence) and target tensor (indexes of the words in
# the target sentence). While creating these vectors we will append the
# EOS token to both sequences.

# %%
def indexesFromSentence(lang, sentence):
    return [lang.word2index[word] for word in sentence.split(' ')]

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(1, -1)

def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

def get_dataloader(batch_size):
    input_lang, output_lang, pairs = prepareData('eng', 'fra', True)

    n = len(pairs)
    input_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)
    target_ids = np.zeros((n, MAX_LENGTH), dtype=np.int32)

    for idx, (inp, tgt) in enumerate(pairs):
        inp_ids = indexesFromSentence(input_lang, inp)
        tgt_ids = indexesFromSentence(output_lang, tgt)
        inp_ids.append(EOS_token)
        tgt_ids.append(EOS_token)
        input_ids[idx, :len(inp_ids)] = inp_ids
        target_ids[idx, :len(tgt_ids)] = tgt_ids

    train_data = TensorDataset(torch.LongTensor(input_ids).to(device),
                               torch.LongTensor(target_ids).to(device))

    train_sampler = RandomSampler(train_data)
    train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)
    return input_lang, output_lang, train_dataloader

# %% [markdown]
# Training the Model
# ==================
#
# To train we run the input sentence through the encoder, and keep track
# of every output and the latest hidden state. Then the decoder is given
# the `<SOS>` token as its first input, and the last hidden state of the
# encoder as its first hidden state.
#
# \"Teacher forcing\" is the concept of using the real target outputs as
# each next input, instead of using the decoder\'s guess as the next
# input. Using teacher forcing causes it to converge faster but [when the
# trained network is exploited, it may exhibit
# instability](http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.378.4095&rep=rep1&type=pdf).
#
# You can observe outputs of teacher-forced networks that read with
# coherent grammar but wander far from the correct translation
# -intuitively it has learned to represent the output grammar and can
# \"pick up\" the meaning once the teacher tells it the first few words,
# but it has not properly learned how to create the sentence from the
# translation in the first place.
#
# Because of the freedom PyTorch\'s autograd gives us, we can randomly
# choose to use teacher forcing or not with a simple if statement. Turn
# `teacher_forcing_ratio` up to use more of it.

# %%
def train_epoch(dataloader, encoder, decoder, encoder_optimizer,
          decoder_optimizer, criterion):

    total_loss = 0
    for data in dataloader:
        input_tensor, target_tensor = data

        encoder_optimizer.zero_grad()
        decoder_optimizer.zero_grad()

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, _, _ = decoder(encoder_outputs, encoder_hidden, target_tensor)

        loss = criterion(
            decoder_outputs.view(-1, decoder_outputs.size(-1)),
            target_tensor.view(-1)
        )
        loss.backward()

        encoder_optimizer.step()
        decoder_optimizer.step()

        total_loss += loss.item()

    return total_loss / len(dataloader)

# %% [markdown]
# This is a helper function to print time elapsed and estimated time
# remaining given the current time and progress %.

# %%
import time
import math

def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# The whole training process looks like this:
#
# -   Start a timer
# -   Initialize optimizers and criterion
# -   Create set of training pairs
# -   Start empty losses array for plotting
#
# Then we call `train` many times and occasionally print the progress (%
# of examples, time so far, estimated time) and average loss.

# %%
def train(train_dataloader, encoder, decoder, n_epochs, learning_rate=0.001,
               print_every=100, plot_every=100):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
    criterion = nn.NLLLoss()

    for epoch in range(1, n_epochs + 1):
        loss = train_epoch(train_dataloader, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion)
        print_loss_total += loss
        plot_loss_total += loss

        if epoch % print_every == 0:
            print_loss_avg = print_loss_total / print_every
            print_loss_total = 0
            print('%s (%d %d%%) %.4f' % (timeSince(start, epoch / n_epochs),
                                        epoch, epoch / n_epochs * 100, print_loss_avg))

        if epoch % plot_every == 0:
            plot_loss_avg = plot_loss_total / plot_every
            plot_losses.append(plot_loss_avg)
            plot_loss_total = 0

    showPlot(plot_losses)

# %% [markdown]
# Plotting results
# ================
#
# Plotting is done with matplotlib, using the array of loss values
# `plot_losses` saved while training.

# %%
import matplotlib.pyplot as plt
plt.switch_backend('agg')
import matplotlib.ticker as ticker
import numpy as np

def showPlot(points):
    plt.figure()
    fig, ax = plt.subplots()
    # this locator puts ticks at regular intervals
    loc = ticker.MultipleLocator(base=0.2)
    ax.yaxis.set_major_locator(loc)
    plt.plot(points)

# %% [markdown]
# Evaluation
# ==========
#
# Evaluation is mostly the same as training, but there are no targets so
# we simply feed the decoder\'s predictions back to itself for each step.
# Every time it predicts a word we add it to the output string, and if it
# predicts the EOS token we stop there. We also store the decoder\'s
# attention outputs for display later.

# %%
def evaluate(encoder, decoder, sentence, input_lang, output_lang):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)

        encoder_outputs, encoder_hidden = encoder(input_tensor)
        decoder_outputs, decoder_hidden, decoder_attn = decoder(encoder_outputs, encoder_hidden)

        _, topi = decoder_outputs.topk(1)
        decoded_ids = topi.squeeze()

        decoded_words = []
        for idx in decoded_ids:
            if idx.item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            decoded_words.append(output_lang.index2word[idx.item()])
    return decoded_words, decoder_attn

# %% [markdown]
# We can evaluate random sentences from the training set and print out the
# input, target, and output to make some subjective quality judgements:

# %%
def evaluateRandomly(encoder, decoder, n=10):
    for i in range(n):
        pair = random.choice(pairs)
        print('>', pair[0])
        print('=', pair[1])
        output_words, _ = evaluate(encoder, decoder, pair[0], input_lang, output_lang)
        output_sentence = ' '.join(output_words)
        print('<', output_sentence)
        print('')

# %% [markdown]
# Training and Evaluating
# =======================
#
# With all these helper functions in place (it looks like extra work, but
# it makes it easier to run multiple experiments) we can actually
# initialize a network and start training.
#
# Remember that the input sentences were heavily filtered. For this small
# dataset we can use relatively small networks of 256 hidden nodes and a
# single GRU layer. After about 40 minutes on a MacBook CPU we\'ll get
# some reasonable results.
#
# <div style="background-color: #54c7ec; color: #fff; font-weight: 700; padding-left: 10px; padding-top: 5px; padding-bottom: 5px"><strong>NOTE:</strong></div>
#
# <div style="background-color: #f3f4f7; padding-left: 10px; padding-top: 10px; padding-bottom: 10px; padding-right: 10px">
#
# <p>If you run this notebook you can train, interrupt the kernel,evaluate, and continue training later. Comment out the lines where theencoder and decoder are initialized and run <code>trainIters</code> again.</p>
#
# </div>

# %%
hidden_size = 128
batch_size = 32

input_lang, output_lang, train_dataloader = get_dataloader(batch_size)

encoder = EncoderRNN(input_lang.n_words, hidden_size).to(device)
decoder = AttnDecoderRNN(hidden_size, output_lang.n_words).to(device)

train(train_dataloader, encoder, decoder, 100, print_every=5, plot_every=5)
# Out:
# Reading lines...
# Read 225 sentence pairs
# Trimmed to 225 sentence pairs
# Counting words...
# Counted words:
# fra 88
# eng 47
# 0m 4s (- 1m 20s) (5 5%) 1.1240
# 0m 8s (- 1m 20s) (10 10%) 0.4821
# 0m 14s (- 1m 19s) (15 15%) 0.3305
# 0m 16s (- 1m 6s) (20 20%) 0.2772
# 0m 18s (- 0m 56s) (25 25%) 0.2570
# 0m 21s (- 0m 49s) (30 30%) 0.2224
# 0m 24s (- 0m 44s) (35 35%) 0.2039
# 0m 26s (- 0m 39s) (40 40%) 0.1846
# 0m 28s (- 0m 35s) (45 45%) 0.1780
# 0m 30s (- 0m 30s) (50 50%) 0.1401
# 0m 33s (- 0m 27s) (55 55%) 0.1102
# 0m 36s (- 0m 24s) (60 60%) 0.0853
# 0m 38s (- 0m 20s) (65 65%) 0.0735
# 0m 40s (- 0m 17s) (70 70%) 0.0614
# 0m 42s (- 0m 14s) (75 75%) 0.0455
# 0m 45s (- 0m 11s) (80 80%) 0.0480
# 0m 48s (- 0m 8s) (85 85%) 0.0468
# 0m 50s (- 0m 5s) (90 90%) 0.0341
# 0m 52s (- 0m 2s) (95 95%) 0.0267
# 0m 54s (- 0m 0s) (100 100%) 0.0235

# %% [markdown]
# Set dropout layers to `eval` mode

# %%
encoder.eval()
decoder.eval()
evaluateRandomly(encoder, decoder)
# Out:
# > kripaya malai janakari dinus ki yo item ajhai available chha ki chhaina ?
# = ho yo item ajhai available chha
# < ho yo item ajhai available chha <EOS>
#
# > yo saman stock ma ajhai pani available chha ki chhaina ? kripaya malai thap janakari dinuhos
# = ho yo saman stock ma ajhai pani available chha
# < ho yo saman stock ma ajhai pani available chha <EOS>
#
# > yo product stock ma chha ki nai ? kripaya bhanidinuhos
# = ho yo product stock ma chha
# < ho yo product stock ma chha tapai le order garna saknuhuncha <EOS>
#
# > yo saman stock ma ajhai pani available chha ki chhaina ?
# = ho yo saman stock ma ajhai pani available chha
# < ho yo saman stock ma ajhai pani available chha <EOS>
#
# > yo product ko availability check garna milchha bhane bhanidinuhos
# = ho tapai yo product ko availability check garna saknuhuncha ajhai stock ma chha
# < ho tapai yo product ko availability check garna saknuhuncha ajhai stock ma chha tapai le order garna saknuhuncha <EOS>
#
# > asha chha ki yo product ajhai stock ma chha ? order garnu chahanchu
# = ho yo product ajhai stock ma chha tapai le order garna saknuhuncha
# < ho yo product ajhai stock ma chha tapai le order garna saknuhuncha <EOS>
#
# > maile yo saman order garna sakchu ki ?
# = ho tapai yo saman order garna saknuhuncha
# < ho tapai yo saman order garna saknuhuncha <EOS>
#
# > kripaya malai janakari dinus ki yo saman hami ko store ma stock ma chha ki chhaina ?
# = ho yo saman hamro store ma stock ma chha
# < ho yo saman hamro store ma stock ma chha <EOS>
#
# > stock update garnu bhayo ki yo item ajhai chha ?
# = ho stock update gareko chha ra yo item ajhai chha
# < ho yo item ko stock update gareko chha ra ajhai pani chha <EOS>
#
# > yo product stock ma ajhai chha bhane janakari dinuhos
# = ho yo product stock ma ajhai chha
# < ho yo product stock ma ajhai chha <EOS>

# %% [markdown]
# Visualizing Attention
# =====================
#
# A useful property of the attention mechanism is its highly interpretable
# outputs. Because it is used to weight specific encoder outputs of the
# input sequence, we can imagine looking where the network is focused most
# at each time step.
#
# You could simply run `plt.matshow(attentions)` to see attention output
# displayed as a matrix. For a better viewing experience we will do the
# extra work of adding axes and labels:

# %%
def showAttention(input_sentence, output_words, attentions):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.cpu().numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_sentence.split(' ') +
                       ['<EOS>'], rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))
    plt.savefig('attention.png')

    plt.show()


def evaluateAndShowAttention(input_sentence):
    output_words, attentions = evaluate(encoder, decoder, input_sentence, input_lang, output_lang)
    print('input =', input_sentence)
    print('output =', ' '.join(output_words))
    showAttention(input_sentence, output_words, attentions[0, :len(output_words), :])


evaluateAndShowAttention("namaste")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-f9046b4386ff> in <cell line: 27>()
#      25
#      26
# ---> 27 evaluateAndShowAttention("namaste")
#
# <ipython-input-23-f9046b4386ff> in evaluateAndShowAttention(input_sentence)
#      19
#      20 def evaluateAndShowAttention(input_sentence):
# ---> 21     output_words, attentions = evaluate(encoder, decoder, input_sentence, input_lang, output_lang)
#      22     print('input =', input_sentence)
#      23     print('output =', ' '.join(output_words))
#
# <ipython-input-19-837e714f35dd> in evaluate(encoder, decoder, sentence, input_lang, output_lang)
#       1 def evaluate(encoder, decoder, sentence, input_lang, output_lang):
#       2     with torch.no_grad():
# ----> 3         input_tensor = tensorFromSentence(input_lang, sentence)
#       4
#       5         encoder_outputs, encoder_hidden = encoder(input_tensor)
#
# <ipython-input-14-6bf43e8ba406> in tensorFromSentence(lang, sentence)
#       3
#       4 def tensorFromSentence(lang, sentence):
# ----> 5     indexes = indexesFromSentence(lang, sentence)
#       6     indexes.append(EOS_token)
#       7     return torch.tensor(indexes, dtype=torch.long, device=device).view(1, -1)
#
# <ipython-input-14-6bf43e8ba406> in indexesFromSentence(lang, sentence)
#       1 def indexesFromSentence(lang, sentence):
# ----> 2     return [lang.word2index[word] for word in sentence.split(' ')]
#       3
#       4 def tensorFromSentence(lang, sentence):
#       5     indexes = indexesFromSentence(lang, sentence)
#
# <ipython-input-14-6bf43e8ba406> in <listcomp>(.0)
#       1 def indexesFromSentence(lang, sentence):
# ----> 2     return [lang.word2index[word] for word in sentence.split(' ')]
#       3
#       4 def tensorFromSentence(lang, sentence):
#       5     indexes = indexesFromSentence(lang, sentence)
#
# KeyError: 'namaste'

# %% [markdown]
# Exercises
# =========
#
# -   Try with a different dataset
#     -   Another language pair
#     -   Human → Machine (e.g. IOT commands)
#     -   Chat → Response
#     -   Question → Answer
# -   Replace the embeddings with pretrained word embeddings such as
#     `word2vec` or `GloVe`
# -   Try with more layers, more hidden units, and more sentences. Compare
#     the training time and results.
# -   If you use a translation file where pairs have two of the same
#     phrase (`I am test \t I am test`), you can use this as an
#     autoencoder. Try this:
#     -   Train as an autoencoder
#     -   Save only the Encoder network
#     -   Train a new Decoder for translation from there
