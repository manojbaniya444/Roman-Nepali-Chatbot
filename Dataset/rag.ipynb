# %%
import pandas as pd

# %%
rag_dataset = pd.read_csv("./v1_fine_tune.csv")

# %%
rag_dataset = rag_dataset.fillna("")

# %%
rag_only = rag_dataset[rag_dataset["category"] == "RAG"]

# %%
rag_only
# Out:
#      category                                             system  \
# 1939      RAG  Talako instruction herera user le gareko quest...
# 1940      RAG  Talako instruction herera user le gareko quest...
# 1941      RAG  Talako instruction herera user le gareko quest...
# 1942      RAG  Talako instruction herera user le gareko quest...
# 1943      RAG  Talako instruction herera user le gareko quest...
# ...       ...                                                ...
# 3252      RAG  Talako instruction herera user le gareko quest...
# 3253      RAG  Talako instruction herera user le gareko quest...
# 3254      RAG  Talako instruction herera user le gareko quest...
# 3255      RAG  Talako instruction herera user le gareko quest...
# 3256      RAG  Talako instruction herera user le gareko quest...
#
#                                             instruction  \
# 1939  User le gareko question lai, context herera mi...
# 1940  User le gareko question lai, context herera mi...
# ...

# %%
rag_only.to_csv("./rag_only.csv", index=False)
